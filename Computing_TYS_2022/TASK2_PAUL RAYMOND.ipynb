# %%
#Task 2.1

def task2_1():
    #Imports
    import random

    #Initialising global list
    global integer_list
    integer_list = []

    for i in range(100):
        integer = random.randint(1,100)
        integer_list.append(integer)

    print(integer_list)
    return integer_list

global_list = task2_1()
# Out:
# [43, 26, 7, 92, 71, 39, 1, 100, 56, 20, 56, 1, 89, 88, 3, 42, 53, 42, 52, 36, 57, 13, 77, 47, 32, 90, 32, 42, 78, 98, 69, 85, 28, 16, 11, 43, 38, 33, 30, 59, 39, 78, 69, 53, 48, 100, 82, 40, 94, 7, 56, 80, 88, 89, 81, 39, 66, 54, 79, 85, 83, 55, 98, 63, 43, 72, 84, 51, 48, 33, 56, 56, 42, 10, 38, 43, 94, 53, 77, 30, 97, 79, 57, 92, 43, 4, 20, 7, 54, 35, 71, 91, 22, 43, 42, 7, 4, 13, 37, 86]

# %%
#Task 2.2

task2_1() #Calls function from task 2.1

def bubbleSort(ar):
    for i in range(len(ar)):
        for j in range(len(ar)-i-1):
            if ar[j] > ar[j+1]:
                ar[j], ar[j+1] = ar[j+1], ar[j] #Swap
    return ar

sorted_list = bubbleSort(integer_list) #Calls bubble sort procedure
print(sorted_list) #Outputs sorted list
# Out:
# [13, 91, 61, 91, 22, 39, 68, 61, 30, 78, 97, 74, 1, 56, 96, 100, 91, 50, 11, 81, 58, 100, 47, 39, 37, 37, 95, 3, 13, 91, 29, 44, 31, 95, 48, 67, 63, 44, 93, 62, 24, 25, 55, 76, 23, 91, 26, 39, 61, 77, 98, 58, 76, 29, 80, 85, 37, 78, 15, 79, 46, 83, 21, 64, 46, 33, 24, 69, 11, 71, 20, 86, 15, 5, 57, 3, 63, 89, 47, 50, 97, 97, 16, 40, 24, 78, 83, 21, 17, 100, 56, 63, 26, 99, 53, 99, 44, 21, 40, 27]
# [1, 3, 3, 5, 11, 11, 13, 13, 15, 15, 16, 17, 20, 21, 21, 21, 22, 23, 24, 24, 24, 25, 26, 26, 27, 29, 29, 30, 31, 33, 37, 37, 37, 39, 39, 39, 40, 40, 44, 44, 44, 46, 46, 47, 47, 48, 50, 50, 53, 55, 56, 56, 57, 58, 58, 61, 61, 61, 62, 63, 63, 63, 64, 67, 68, 69, 71, 74, 76, 76, 77, 78, 78, 78, 79, 80, 81, 83, 83, 85, 86, 89, 91, 91, 91, 91, 91, 93, 95, 95, 96, 97, 97, 97, 98, 99, 99, 100, 100, 100]

# %%
#Task 2.3

def mergeSortProcedure(ar):

    def mergeSort(ar):

        if len(ar) <= 1:
            return ar

        mid = len(ar) // 2

        left_ar = mergeSort(ar[0:mid])
        right_ar = mergeSort(ar[mid:])

        return merge(left_ar, right_ar)

    def merge(left, right):

        sorted_ar = []

        i = 0
        j = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                sorted_ar.append(left[i])
                i += 1
            else:
                sorted_ar.append(right[j])
                j += 1

        sorted_ar.extend(left[i:])
        sorted_ar.extend(right[j:])

        return sorted_ar

    return mergeSort(ar)

unsorted_list = task2_1()
choice = input("Which sorting algorithm would you prefer (bubble, merge): ")
while choice != "bubble" and choice != "merge":
    print("Invalid input!")
    choice = input("Which sorting algorithm would you prefer (bubble, merge): ")

if choice == "bubble":
    sorted_list = bubbleSort(unsorted_list)
else:
    sorted_list = mergeSortProcedure(unsorted_list)

print(sorted_list)
# Out:
# [62, 89, 70, 96, 27, 68, 2, 19, 38, 52, 75, 93, 46, 41, 45, 59, 15, 12, 71, 37, 64, 51, 89, 85, 40, 53, 96, 48, 16, 82, 85, 31, 61, 15, 81, 72, 54, 100, 55, 59, 36, 33, 53, 6, 7, 62, 44, 9, 36, 58, 6, 95, 93, 84, 22, 72, 57, 23, 87, 58, 6, 95, 95, 100, 94, 27, 74, 69, 67, 78, 75, 23, 1, 22, 55, 29, 11, 87, 46, 8, 51, 16, 91, 93, 37, 97, 23, 25, 56, 98, 3, 100, 37, 28, 3, 89, 32, 68, 18, 26]
# Which sorting algorithm would you prefer (bubble, merge):  buble
# Invalid input!
# Which sorting algorithm would you prefer (bubble, merge):  bubble
# [1, 2, 3, 3, 6, 6, 6, 7, 8, 9, 11, 12, 15, 15, 16, 16, 18, 19, 22, 22, 23, 23, 23, 25, 26, 27, 27, 28, 29, 31, 32, 33, 36, 36, 37, 37, 37, 38, 40, 41, 44, 45, 46, 46, 48, 51, 51, 52, 53, 53, 54, 55, 55, 56, 57, 58, 58, 59, 59, 61, 62, 62, 64, 67, 68, 68, 69, 70, 71, 72, 72, 74, 75, 75, 78, 81, 82, 84, 85, 85, 87, 87, 89, 89, 89, 91, 93, 93, 93, 94, 95, 95, 95, 96, 96, 97, 98, 100, 100, 100]

# %%
#Task 2.4

def binarySearchRecursive(ar, low, high, target):

    if low > high: #Case if element not found
        return -1

    mid = (low + high ) // 2

    if ar[mid] == target: #Case if found
        return mid

    if ar[mid] < target: #Case if element is less than target
        return binarySearchRecursive(ar, mid + 1, high, target)

    if ar[mid] > target:
        return binarySearchRecursive(ar, low, mid - 1, target) #Case if element greater than target

def prompt():
    user_input = int(input("Enter target integer: "))

    data_list = task2_1()

    result = binarySearchRecursive(data_list, 0, len(data_list)-1, user_input)

    if result == -1:
        print("Not Found")
    else:
        print(result)

#Main Program
prompt()
prompt()
# Out:
# Enter target integer:  1
# [66, 7, 59, 85, 64, 34, 44, 54, 3, 48, 4, 84, 26, 37, 99, 20, 62, 9, 13, 36, 65, 73, 59, 5, 29, 12, 44, 29, 92, 43, 42, 47, 27, 11, 23, 66, 96, 10, 74, 86, 21, 33, 25, 94, 62, 62, 9, 76, 90, 76, 82, 12, 79, 21, 18, 36, 32, 50, 1, 29, 35, 79, 91, 6, 79, 58, 17, 41, 6, 17, 78, 33, 11, 56, 47, 49, 1, 62, 100, 64, 41, 64, 70, 25, 4, 86, 57, 86, 9, 43, 80, 26, 63, 5, 39, 26, 87, 48, 19, 12]
# Not Found
# Enter target integer:  234
# [61, 3, 66, 93, 90, 100, 12, 86, 42, 1, 93, 95, 92, 74, 92, 34, 37, 54, 42, 81, 22, 13, 49, 64, 36, 8, 26, 55, 80, 33, 40, 15, 5, 50, 8, 14, 95, 59, 91, 50, 77, 19, 86, 89, 64, 11, 28, 74, 19, 47, 26, 22, 50, 87, 77, 80, 7, 39, 56, 83, 2, 74, 56, 64, 13, 16, 16, 18, 89, 14, 52, 28, 25, 92, 20, 44, 29, 15, 35, 44, 37, 88, 92, 27, 57, 81, 3, 28, 79, 42, 11, 97, 91, 78, 30, 37, 30, 50, 52, 15]
# Not Found
