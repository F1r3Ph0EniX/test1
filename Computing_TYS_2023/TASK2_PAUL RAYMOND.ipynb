# %%
#Task 2.1

class QueueItem:
    def __init__(self, ID, quantity):
        self.ID = ID
        self.quantity = quantity

    #Get & Set methods
    def getID(self):
        return self.ID

    #def set_id(self, newID):
        #self.ID = newID
        #return True

    def getQuantity(self):
        return self.quantity

    #def set_quantity(self, newQuantity):
        #self.quantity = newQuantity
        #return True

class Queue:
    def __init__(self):
        self.queueList = [None]*4
        self.headPointer = 0
        self.tailPointer = 0
        self.numberItems = 0


#Main Program
#Q = Queue()
# Out:
# True

# %%
class QueueItem:
    def __init__(self, ID, quantity):
        self.ID = ID
        self.quantity = quantity

    #Get & Set methods
    def getID(self):
        return self.ID

    #def set_id(self, newID):
        #self.ID = newID
        #return True

    def getQuantity(self):
        return self.quantity

    #def set_quantity(self, newQuantity):
        #self.quantity = newQuantity
        #return True

class Queue:
    def __init__(self):
        self.queueList = [None]*4
        self.headPointer = 0
        self.tailPointer = 0
        self.numberItems = 0

    #Functions & Procedures
    def enqueue(self, QueueItem):

        if self.numberItems == len(self.queueList): #Case if queue full
            print("Queue is full!") #Debugging
            return False
        else: #Case if otherwise
            self.queueList[self.tailPointer] = QueueItem
            self.tailPointer = (self.tailPointer + 1) % 4

            self.numberItems += 1
            print("Item successfully added.")
            return True

set1 = QueueItem("Broccoli", 5)
set2 = QueueItem("Chicken Breast", 2)
set3 = QueueItem("Medium Biscuits Pack", 1)
set4 = QueueItem("Fresh Bread Loaf", 1)
set5 = QueueItem("Ketchup 100ml", 2)
fivesets = [set1,set2,set3,set4,set5]

Q = Queue()
for set in fivesets:
    Q.enqueue(set)
# Out:
# Item successfully added.
# Item successfully added.
# Item successfully added.
# Item successfully added.
# Queue is full!

# %%
class QueueItem:
    def __init__(self, ID, quantity):
        self.ID = ID
        self.quantity = quantity

    #Get & Set methods
    def getID(self):
        return self.ID

    def getQuantity(self):
        return self.quantity

class Queue:
    def __init__(self):
        self.queueList = [None]*4
        self.headPointer = 0
        self.tailPointer = 0
        self.numberItems = 0

    #Functions & Procedures
    def enqueue(self, QueueItem):

        if self.numberItems == len(self.queueList): #Case if queue full
            print("Queue is full!") #Debugging
            return False
        else: #Case if otherwise
            self.queueList[self.tailPointer] = QueueItem
            self.tailPointer = (self.tailPointer + 1) % 4

            self.numberItems += 1
            return True

    def dequeue(self):

        if self.numberItems == 0: #Case if empty
            print("Queue is empty.")
            return False

        temp = self.queueList[self.headPointer]
        self.headPointer = (self.headPointer + 1) % 4
        self.numberItems -= 1

        print(temp.getID())
        return temp

set1 = QueueItem("Broccoli", 5)
set2 = QueueItem("Chicken Breast", 2)
set3 = QueueItem("Medium Biscuits Pack", 1)
set4 = QueueItem("Fresh Bread Loaf", 1)
set5 = QueueItem("Ketchup 100ml", 2)
fivesets = [set1,set2,set3,set4,set5]

Q = Queue()
for set in fivesets:
    Q.enqueue(set)

Q.dequeue()
Q.dequeue()
Q.dequeue()
Q.dequeue()
Q.dequeue()
# Out:
# Queue is full!
# Broccoli
# Chicken Breast
# Medium Biscuits Pack
# Fresh Bread Loaf
# Queue is empty.
# False

# %%
class QueueItem:
    def __init__(self, ID, quantity):
        self.ID = ID
        self.quantity = quantity

    #Get & Set methods
    def getID(self):
        return self.ID

    def getQuantity(self):
        return self.quantity

class Queue:
    def __init__(self):
        self.queueList = [None]*4
        self.headPointer = 0
        self.tailPointer = 0
        self.numberItems = 0

    #Functions & Procedures
    def enqueue(self, QueueItem):

        if self.numberItems == len(self.queueList): #Case if queue full
            print("Queue is full!") #Debugging
            return False
        else: #Case if otherwise
            self.queueList[self.tailPointer] = QueueItem
            self.tailPointer = (self.tailPointer + 1) % 4

            self.numberItems += 1
            return True

    def dequeue(self):

        if self.numberItems == 0: #Case if empty
            return False

        temp = self.queueList[self.headPointer]
        self.headPointer = (self.headPointer + 1) % 4
        self.numberItems -= 1
        return temp

    def printQueue(self):

        current = self.headPointer

        for i in range(self.numberItems):
            item = self.queueList[current]
            print(item.getID(), item.getQuantity())
            current = (current + 1) % 4

#Main Program
set1 = QueueItem("Scissors", 1)
set2 = QueueItem("2B Pencil", 2)
set3 = QueueItem("Blue Gel Pen", 2)
set4 = QueueItem("Eraser", 1)
foursets = [set1,set2,set3,set4]

Q = Queue()
for set in foursets:
    Q.enqueue(set)

Q.printQueue()
# Out:
# Scissors 1
# 2B Pencil 2
# Blue Gel Pen 2
# Eraser 1
